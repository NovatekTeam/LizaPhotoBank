# %%
from pathlib import Path
import os
import pandas as pd

# %%
dir_path = Path(os.path.join('..','tmp'))
dataset_path = Path(os.path.join('..','dataset','objects'))
data_path = dataset_path.joinpath('data.csv')

# %% [markdown]
# ### CVAT download dataset

# %%
import requests
import shutil
import sys
from glob import glob
import cv2
sys.path.insert(0, "..")
from zipfile import ZipFile

from io import BytesIO

# %%
URL = 'http://10.72.125.105:8080'
API_URL = '%s/api/v1' % URL
LOGIN = 'ml'
PASSWORD = 'NuAzu8mO'
PROJECT = 'Liza'

def get_session(url, username, password):
    session = requests.Session()
    response=session.post(url, data={'username':username,'password':password})
    response.raise_for_status()
    if 'csrftoken' in response.cookies:
        session.headers['X-CSRFToken'] = response.cookies['csrftoken']
    return session

def get_request(self, method, query=None):
    url = "%s/%s" % (API_URL,method)
    if ~(query is None):
        url+='?%s'%query
    request = self.get(url)
    if request.headers['Content-Type'] == 'application/json':
        return request.json()
    else:
        return request

# %%
url = '%s/auth/login' % API_URL
session = get_session(url, LOGIN, PASSWORD)
projects = get_request(session,'projects','?search=%s' % (PROJECT))
project= projects['results'][0]

# %%
labels=pd.DataFrame(project['labels'])

# %%
def makePath(path):
    if path.exists() and path.is_dir():
        shutil.rmtree(path)
    os.mkdir(path)

# %%
makePath(dir_path)
makePath(dataset_path)

for task in project['tasks']:
    task_id = task['id']
    chunk_size = task['data_chunk_size']
    annotations = get_request(session,'tasks/%s/annotations' % (task_id))
    shapes = pd.DataFrame(annotations['shapes'])
    chunk_number=0

    for chunk_n in range((shapes.frame.max() // chunk_size) + 1):
        start_chunk = chunk_n * chunk_size
        chunk_shapes = shapes[(shapes.frame >= start_chunk) & (shapes.frame < start_chunk+chunk_size)]

        if len(chunk_shapes) > 0:
            data=get_request(session,'tasks/%s/data' % task_id, 'type=chunk&number=%s&quality=original' % chunk_n)
            zipfile= ZipFile(BytesIO(data.content))
            zipfile.extractall(dir_path)

            for frame in chunk_shapes.frame.unique():
                filename = '%s.*' % str(1000000 + (frame-start_chunk))[1:]
                filename = glob(str(dir_path.joinpath(filename)))[0]
                image_id = '%s_%s' % (task_id,frame)
                new_filename = ('%s.%s' % (image_id, filename.split('.')[-1])).lower()
                shapes.loc[shapes['frame']==frame, 'image_path'] = new_filename
                shutil.move(dir_path.joinpath(filename),dataset_path.joinpath(new_filename))


shutil.rmtree(dir_path)

# %% [markdown]
# ### Label objects

# %%
shapes['label']=shapes.apply(lambda x: labels[labels['id']==x.label_id].index[0], axis=1)

boxes=pd.DataFrame(shapes['points'].to_list(), columns=['x1', 'y1', 'x2', 'y2'])
shapes=pd.concat([shapes,boxes], axis=1)

images_path = dataset_path.joinpath('images')
labels_path = dataset_path.joinpath('labels')
makePath(images_path)
makePath(labels_path)

# %%
for image in shapes.image_path.unique():
    im=cv2.imread(str(dataset_path.joinpath(image)))
    shutil.move(dataset_path.joinpath(image),images_path.joinpath(image))
    coords = shapes[shapes['image_path']==image][['label','x1', 'y1', 'x2', 'y2']]
    width = im.shape[1]
    height = im.shape[0]
    
    txt_path = labels_path.joinpath('%s.txt' % image.split('.')[0])
    coords.apply(lambda x: pd.Series([
        x.label, 
        ((x.x2+x.x1)/2)/width, 
        (((x.y2+x.y1)/2)/height), 
        (x.x2-x.x1)/width, 
        (x.y2-x.y1)/height])
    , axis=1).to_csv(txt_path, sep=' ', index=None, header=None)

# %%
labels.name.unique()
# Out:
# array(['drons', 'auto', 'swimmer', 'horse', 'hug', 'sherp', 'aero', 'dog'],
#       dtype=object)

# %% [markdown]
# ### Train YOLOv5

# %%
# !python3 ../yolov5/train.py --img 800 --batch 16 --epochs 3 --data liza.yaml --weights yolov5s.pt
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5s.pt, cfg=, data=liza.yaml, hyp=../yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=800, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=../yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-261-g19f33cb Python-3.8.10 torch-1.10.0+cu102 CUDA:0 (GRID P40-12Q, 12288MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir ../yolov5/runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=8
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     35061  models.yolo.Detect                      [8, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7041205 parameters, 7041205 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
# albumentations: Blur(always_apply=False, p=0.01, blur_limit=(3, 7)), MedianBlur(always_apply=False, p=0.01, blur_limit=(3, 7)), ToGray(always_apply=False, p=0.01), CLAHE(always_apply=False, p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning '/data_new/Projects/LizaPhotoBank/dataset/objects/labels' images
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1040.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1041.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1042.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1043.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1044.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1045.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1046.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1047.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1048.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1049.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1050.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1051.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1053.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0575]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1076.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1077.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1085.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0757      1.0657      1.6286]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1090.jpg: ignoring corrupt image/label: negative label values [   -0.17584]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_111.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1112.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1118.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1123.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1148.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1149.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1150.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1151.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1158.jpg: ignoring corrupt image/label: negative label values [  -0.019688]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1159.jpg: ignoring corrupt image/label: negative label values [  -0.010678]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1160.jpg: ignoring corrupt image/label: negative label values [  -0.015158]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1161.jpg: ignoring corrupt image/label: negative label values [  -0.018186]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1175.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2695]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1176.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2732]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1184.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1185.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1186.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1187.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1188.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1189.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1190.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1191.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1192.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1193.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1194.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1195.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1220.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1221.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1222.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1223.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_125.jpg: ignoring corrupt image/label: negative label values [   -0.86452    -0.89355    -0.67026]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1256.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1257.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1258.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1259.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_126.jpg: ignoring corrupt image/label: negative label values [   -0.97817    -0.92012]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1260.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1261.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1262.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1263.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1264.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1265.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1266.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1267.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1268.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.469]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1269.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3413]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_127.jpg: ignoring corrupt image/label: negative label values [    -1.0208    -0.68141]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_129.jpg: ignoring corrupt image/label: negative label values [   -0.60306    -0.21454    -0.97818]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1292.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1293.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1294.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1295.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_131.jpg: ignoring corrupt image/label: negative label values [   -0.90695    -0.81093      -0.735]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1328.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1329.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_133.jpg: ignoring corrupt image/label: negative label values [   -0.87212]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1330.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1331.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1332.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1333.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1334.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1335.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1336.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1337.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1338.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1339.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_134.jpg: ignoring corrupt image/label: negative label values [    -1.0337]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_136.jpg: ignoring corrupt image/label: negative label values [   -0.86404]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1364.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1365.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1366.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1367.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1368.jpg: ignoring corrupt image/label: negative label values [   -0.24417   -0.038917]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1369.jpg: ignoring corrupt image/label: negative label values [   -0.25177  -0.0034426   -0.041451]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_137.jpg: ignoring corrupt image/label: negative label values [   -0.71589]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1370.jpg: ignoring corrupt image/label: negative label values [   -0.26064   -0.047787]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1371.jpg: ignoring corrupt image/label: negative label values [   -0.27584   -0.041451   -0.065524]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1372.jpg: ignoring corrupt image/label: negative label values [   -0.07946   -0.092131]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_1373.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1042      1.4434]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_138.jpg: ignoring corrupt image/label: negative label values [    -1.0041]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_139.jpg: ignoring corrupt image/label: negative label values [   -0.41151]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_140.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_141.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_142.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_143.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_145.jpg: ignoring corrupt image/label: negative label values [    -1.7086]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_146.jpg: ignoring corrupt image/label: negative label values [    -0.8232]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_147.jpg: ignoring corrupt image/label: negative label values [    -1.5181]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_148.jpg: ignoring corrupt image/label: negative label values [    -1.5334]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_149.jpg: ignoring corrupt image/label: negative label values [   -0.52996]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_150.jpg: ignoring corrupt image/label: negative label values [     -1.678]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_151.jpg: ignoring corrupt image/label: negative label values [    -1.2845]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_152.jpg: ignoring corrupt image/label: negative label values [    -1.3509]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_153.jpg: ignoring corrupt image/label: negative label values [   -0.55387]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_154.jpg: ignoring corrupt image/label: negative label values [    -2.0662]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_155.jpg: ignoring corrupt image/label: negative label values [    -3.0563]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_156.jpg: ignoring corrupt image/label: negative label values [    -3.2438]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_157.jpg: ignoring corrupt image/label: negative label values [    -3.0519]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_159.jpg: ignoring corrupt image/label: negative label values [    -1.9397]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_160.jpg: ignoring corrupt image/label: negative label values [    -1.3771]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_161.jpg: ignoring corrupt image/label: negative label values [    -2.3148]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_162.jpg: ignoring corrupt image/label: negative label values [     -2.088]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_163.jpg: ignoring corrupt image/label: negative label values [    -1.2017]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_164.jpg: ignoring corrupt image/label: negative label values [    -1.2498]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_165.jpg: ignoring corrupt image/label: negative label values [    -1.3209]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_166.jpg: ignoring corrupt image/label: negative label values [    -1.5213]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_167.jpg: ignoring corrupt image/label: negative label values [    -2.1481]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_168.jpg: ignoring corrupt image/label: negative label values [     -1.851]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_171.jpg: ignoring corrupt image/label: negative label values [  -0.073114]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_172.jpg: ignoring corrupt image/label: negative label values [  -0.018449]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_174.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2005]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_230.jpg: ignoring corrupt image/label: negative label values [    -2.3584     -1.0631    -0.61385     -1.7304     -1.6213     -1.4905     -1.3771    -0.38705     -1.3117    -0.94968     -2.6158     -2.1709       -1.05]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_231.jpg: ignoring corrupt image/label: negative label values [    -3.7061     -3.1217     -1.7827     -2.0139     -1.5516    -0.65746    -0.97149       -1.46     -1.4687      -1.412     -1.3509     -1.3596    -0.98021     -1.1023     -1.8394     -1.2942     -1.2942     -1.2637]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_232.jpg: ignoring corrupt image/label: negative label values [    -3.0519     -2.2319     -2.8643     -1.8263     -2.2407     -2.1883     -1.6213      -1.569     -1.6824     -1.4207     -1.0762     -1.6301     -1.6083     -1.6213      -1.665      -1.678     -1.7391      -1.726]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_233.jpg: ignoring corrupt image/label: negative label values [    -1.8002      -1.665     -1.5777     -1.3117     -1.0674     -1.0369     -1.4164      -1.678     -1.5734     -1.2157     -1.3684]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_234.jpg: ignoring corrupt image/label: negative label values [   -0.86681    -0.87117     -1.3727      -3.584     -2.8993     -1.7304    -0.53098    -0.21259    -0.22568    -0.25185    -0.26929     -1.3864     -1.2781     -1.1539     -1.9025     -1.7065     -1.1137    -0.96524    -0.83379    -0.71937     -1.5751     -1.4521     -1.2841     -1.1271    -0.43454     -0.2897
#     -0.17893     -0.8277    -0.70841    -0.53314    -0.32499     -2.3251     -2.6758]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_235.jpg: ignoring corrupt image/label: negative label values [   -0.42194    -0.74469     -2.1185     -1.0413     -1.0413     -1.8438     -3.1479]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_236.jpg: ignoring corrupt image/label: negative label values [    -1.0688       -1.67     -1.3435     -1.6926     -1.8413     -1.2983      -1.266     -1.2142]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_237.jpg: ignoring corrupt image/label: negative label values [    -2.2583    -0.52251    -0.82957     -0.3221      -0.432    -0.60978]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_238.jpg: ignoring corrupt image/label: negative label values [   -0.91038     -1.2207    -0.82311    -0.01503]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_239.jpg: ignoring corrupt image/label: negative label values [    -1.7993     -2.4199     -1.4405     -1.7742     -1.9411     -2.0394      -2.136     -2.2568     -1.4856]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_240.jpg: ignoring corrupt image/label: negative label values [    -2.4296     -2.3423     -2.2583     -2.0288     -1.3657     -2.2012      -2.131     -2.0204     -1.8021     -1.7522]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_241.jpg: ignoring corrupt image/label: negative label values [   -0.28702]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_242.jpg: ignoring corrupt image/label: negative label values [   -0.35119  -0.0089424]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_244.jpg: ignoring corrupt image/label: negative label values [  -0.083809]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_245.jpg: ignoring corrupt image/label: negative label values [   -0.12778]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_246.jpg: ignoring corrupt image/label: negative label values [   -0.14781    -0.13385    -0.15248   -0.057972]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_247.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4647      1.2588]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_248.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0827]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_249.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2313      1.0504]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_250.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_251.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_252.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_253.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_254.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_255.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_256.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_257.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_258.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_259.jpg: ignoring corrupt image/label: negative label values [    -0.7562]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_260.jpg: ignoring corrupt image/label: negative label values [   -0.77051]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_261.jpg: ignoring corrupt image/label: negative label values [    -2.1546]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_262.jpg: ignoring corrupt image/label: negative label values [   -0.89607     -1.0157]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_263.jpg: ignoring corrupt image/label: negative label values [   -0.16522     -1.2143     -1.2101]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_264.jpg: ignoring corrupt image/label: negative label values [   -0.20404     -1.6892]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_265.jpg: ignoring corrupt image/label: negative label values [    -1.5936     -1.3401]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_266.jpg: ignoring corrupt image/label: negative label values [    -1.5934     -1.3169]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_267.jpg: ignoring corrupt image/label: negative label values [    -1.7333]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_268.jpg: ignoring corrupt image/label: negative label values [   -0.31404    -0.56602]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_276.jpg: ignoring corrupt image/label: negative label values [    -1.1415     -1.2151]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_277.jpg: ignoring corrupt image/label: negative label values [   -0.55562    -0.88263]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_278.jpg: ignoring corrupt image/label: negative label values [   -0.83745     -1.3414     -1.3693]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_279.jpg: ignoring corrupt image/label: negative label values [   -0.59369     -1.1483     -1.0864]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_281.jpg: ignoring corrupt image/label: negative label values [    -0.8768    -0.81762    -0.38922]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_282.jpg: ignoring corrupt image/label: negative label values [   -0.65111     -0.9933     -1.0304    -0.94482]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_284.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_285.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_286.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_287.jpg: ignoring corrupt image/label: negative label values [  -0.050675   -0.027547]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_288.jpg: ignoring corrupt image/label: negative label values [    -1.7578     -2.0922     -1.8648]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_289.jpg: ignoring corrupt image/label: negative label values [    -1.7732     -1.6294     -1.5135     -1.4717]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_290.jpg: ignoring corrupt image/label: negative label values [    -1.9332     -1.7659     -1.8654     -1.8157]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_291.jpg: ignoring corrupt image/label: negative label values [    -1.5538     -1.5491     -1.5259]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_292.jpg: ignoring corrupt image/label: negative label values [    -1.5727     -1.3288     -1.6253     -2.0031]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_293.jpg: ignoring corrupt image/label: negative label values [   -0.69283    -0.90133]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_294.jpg: ignoring corrupt image/label: negative label values [  -0.003164]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_295.jpg: ignoring corrupt image/label: negative label values [    -1.7574    -0.52342     -1.9547]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_296.jpg: ignoring corrupt image/label: negative label values [    -1.7394     -1.6375     -1.7162     -1.6931]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_297.jpg: ignoring corrupt image/label: negative label values [    -2.1208     -1.9504     -2.0924     -2.0403]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_298.jpg: ignoring corrupt image/label: negative label values [    -2.3258     -1.9629      -1.521     -2.0001]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_299.jpg: ignoring corrupt image/label: negative label values [    -2.3475     -2.0031     -1.6397     -2.0557]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_300.jpg: ignoring corrupt image/label: negative label values [    -2.4718]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_301.jpg: ignoring corrupt image/label: negative label values [    -2.4675]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_302.jpg: ignoring corrupt image/label: negative label values [     -2.551]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_303.jpg: ignoring corrupt image/label: negative label values [    -2.5627]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_304.jpg: ignoring corrupt image/label: negative label values [    -1.7497]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_305.jpg: ignoring corrupt image/label: negative label values [     -1.587]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_306.jpg: ignoring corrupt image/label: negative label values [    -1.7736]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_307.jpg: ignoring corrupt image/label: negative label values [    -3.4152]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_308.jpg: ignoring corrupt image/label: negative label values [    -1.2965]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_309.jpg: ignoring corrupt image/label: negative label values [    -1.2611]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_310.jpg: ignoring corrupt image/label: negative label values [    -1.3391]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_311.jpg: ignoring corrupt image/label: negative label values [    -1.3603]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_312.jpg: ignoring corrupt image/label: negative label values [   -0.90668]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_318.jpg: ignoring corrupt image/label: negative label values [   -0.77545]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_32.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_320.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_321.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_322.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_323.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_324.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_325.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_326.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_327.jpg: ignoring corrupt image/label: negative label values [  -0.047458]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_328.jpg: ignoring corrupt image/label: negative label values [ -0.0091067   -0.096388]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_329.jpg: ignoring corrupt image/label: negative label values [  -0.067294]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_33.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_331.jpg: ignoring corrupt image/label: negative label values [  -0.090235]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_332.jpg: ignoring corrupt image/label: negative label values [   -0.58808]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_333.jpg: ignoring corrupt image/label: negative label values [   -0.83838]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_334.jpg: ignoring corrupt image/label: negative label values [    -0.8783    -0.62822    -0.85023]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_335.jpg: ignoring corrupt image/label: negative label values [   -0.70988    -0.57463]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_336.jpg: ignoring corrupt image/label: negative label values [   -0.79664    -0.44449]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_337.jpg: ignoring corrupt image/label: negative label values [   -0.64228     -0.6528    -0.60022    -0.62546    -0.58971]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_338.jpg: ignoring corrupt image/label: negative label values [   -0.40255]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_339.jpg: ignoring corrupt image/label: negative label values [   -0.29324]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_340.jpg: ignoring corrupt image/label: negative label values [   -0.69906]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_341.jpg: ignoring corrupt image/label: negative label values [   -0.33315]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_342.jpg: ignoring corrupt image/label: negative label values [   -0.30792]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_343.jpg: ignoring corrupt image/label: negative label values [   -0.74743    -0.76425    -0.69275     -0.6549]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_344.jpg: ignoring corrupt image/label: negative label values [   -0.31213    -0.36049    -0.43409]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_345.jpg: ignoring corrupt image/label: negative label values [   -0.41307    -0.38152     -0.3689    -0.33736    -0.27848]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_346.jpg: ignoring corrupt image/label: negative label values [   -0.49928    -0.45933    -0.45302    -0.39834]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_347.jpg: ignoring corrupt image/label: negative label values [     -0.575    -0.57709    -0.54556]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_348.jpg: ignoring corrupt image/label: negative label values [   -0.83154]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_349.jpg: ignoring corrupt image/label: negative label values [   -0.41937    -0.41727    -0.40255    -0.39622    -0.37101    -0.36049]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_350.jpg: ignoring corrupt image/label: negative label values [   -0.74532    -0.71168    -0.72219    -0.67593    -0.62546    -0.56237]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_351.jpg: ignoring corrupt image/label: negative label values [   -0.82103    -0.82523     -0.7264    -0.60022]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_352.jpg: ignoring corrupt image/label: negative label values [   -0.81051    -0.79159    -0.71799     -0.5939]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_353.jpg: ignoring corrupt image/label: negative label values [   -0.81262    -0.77476    -0.69695    -0.61705]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_354.jpg: ignoring corrupt image/label: negative label values [    -0.9472    -0.84626    -0.82523    -0.61074]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_355.jpg: ignoring corrupt image/label: negative label values [   -0.60233    -0.99767     -1.0187]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_356.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_357.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_358.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_359.jpg: ignoring corrupt image/label: negative label values [ -0.0042949   -0.019436  -0.0042948  -0.0017716]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_360.jpg: ignoring corrupt image/label: negative label values [     -1.557     -1.6319     -1.5843     -1.7049     -1.4966     -1.7027]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_361.jpg: ignoring corrupt image/label: negative label values [    -1.8362     -1.9179     -1.8567     -1.8226]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_362.jpg: ignoring corrupt image/label: negative label values [    -1.6387     -1.7239     -1.6558     -1.6353     -1.6626]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_363.jpg: ignoring corrupt image/label: negative label values [    -1.8737]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_364.jpg: ignoring corrupt image/label: negative label values [    -1.9316]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_365.jpg: ignoring corrupt image/label: negative label values [   -0.34896    -0.43754    -0.78275    -0.77139    -0.70325]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_366.jpg: ignoring corrupt image/label: negative label values [    -1.2233     -1.6047     -1.5604     -1.4991]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_367.jpg: ignoring corrupt image/label: negative label values [    -1.6387     -1.5502     -1.1757]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_368.jpg: ignoring corrupt image/label: negative label values [    -1.9656     -1.9759     -2.1155]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_369.jpg: ignoring corrupt image/label: negative label values [    -1.4753     -1.0633     -1.0224]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_37.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_370.jpg: ignoring corrupt image/label: negative label values [     -1.145     -1.2097]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_371.jpg: ignoring corrupt image/label: negative label values [    -3.5884]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_372.jpg: ignoring corrupt image/label: negative label values [    -3.4961]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_373.jpg: ignoring corrupt image/label: negative label values [    -1.1825]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_374.jpg: ignoring corrupt image/label: negative label values [    -1.0905]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_375.jpg: ignoring corrupt image/label: negative label values [    -1.0973]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_376.jpg: ignoring corrupt image/label: negative label values [    -1.2301]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_377.jpg: ignoring corrupt image/label: negative label values [    -1.9384     -1.7443]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_378.jpg: ignoring corrupt image/label: negative label values [    -1.8192     -1.9077]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_379.jpg: ignoring corrupt image/label: negative label values [    -1.9009     -1.6387     -1.2982     -1.3936]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_38.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_380.jpg: ignoring corrupt image/label: negative label values [   -0.64772    -0.74867]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_381.jpg: ignoring corrupt image/label: negative label values [   -0.55184    -0.63007]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_382.jpg: ignoring corrupt image/label: negative label values [   -0.40548    -0.62754]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_383.jpg: ignoring corrupt image/label: negative label values [   -0.61745     -1.0313]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_384.jpg: ignoring corrupt image/label: negative label values [    -1.3709]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_385.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.098]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_386.jpg: ignoring corrupt image/label: negative label values [   -0.10351]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_39.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_390.jpg: ignoring corrupt image/label: negative label values [  -0.062266    -0.24672]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_392.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_393.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_394.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_395.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_396.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_397.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_398.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_399.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_40.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_400.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_401.jpg: corrupt JPEG restored and saved
# ...
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_793.jpg: ignoring corrupt image/label: negative label values [      -1.83]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_798.jpg: ignoring corrupt image/label: negative label values [   -0.86053]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_799.jpg: ignoring corrupt image/label: negative label values [    -2.4905]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_800.jpg: ignoring corrupt image/label: negative label values [    -1.8165     -1.1359     -0.9019     -1.0122     -1.4103     -1.5125     -1.6228]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_803.jpg: ignoring corrupt image/label: negative label values [   -0.40292    -0.11369]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_804.jpg: ignoring corrupt image/label: negative label values [  -0.066692]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_824.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_825.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_826.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_827.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_828.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_829.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_830.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_831.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_832.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_833.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_860.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_861.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_862.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_863.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_864.jpg: ignoring corrupt image/label: negative label values [    -1.2446]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_865.jpg: ignoring corrupt image/label: negative label values [    -1.2829]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_866.jpg: ignoring corrupt image/label: negative label values [   -0.98322]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_867.jpg: ignoring corrupt image/label: negative label values [    -1.0501]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_868.jpg: ignoring corrupt image/label: negative label values [    -1.1426]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_869.jpg: ignoring corrupt image/label: negative label values [   -0.81535]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_870.jpg: ignoring corrupt image/label: negative label values [    -1.6824]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_871.jpg: ignoring corrupt image/label: negative label values [    -1.0023]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_872.jpg: ignoring corrupt image/label: negative label values [   -0.99271]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_875.jpg: ignoring corrupt image/label: negative label values [    -1.6606]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_876.jpg: ignoring corrupt image/label: negative label values [    -3.3136]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_877.jpg: ignoring corrupt image/label: negative label values [    -2.5678]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_878.jpg: ignoring corrupt image/label: negative label values [    -1.9659]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_879.jpg: ignoring corrupt image/label: negative label values [    -2.7771]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_880.jpg: ignoring corrupt image/label: negative label values [    -0.7665     -2.5111      -2.293]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_881.jpg: ignoring corrupt image/label: negative label values [    -2.2974     -1.1546     -2.3715     -2.4718]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_882.jpg: ignoring corrupt image/label: negative label values [    -2.8295     -2.2538]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_883.jpg: ignoring corrupt image/label: negative label values [    -2.3584]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_884.jpg: ignoring corrupt image/label: negative label values [    -1.1787]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_885.jpg: ignoring corrupt image/label: negative label values [    -1.4696]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_886.jpg: ignoring corrupt image/label: negative label values [    -2.0999]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_887.jpg: ignoring corrupt image/label: negative label values [    -2.0255]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_888.jpg: ignoring corrupt image/label: negative label values [    -1.5246]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_892.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1127]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_893.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1314]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_894.jpg: ignoring corrupt image/label: negative label values [   -0.33058]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_896.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0867]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_897.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.065]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_908.jpg: ignoring corrupt image/label: negative label values [    -1.3864]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_913.jpg: ignoring corrupt image/label: negative label values [   -0.62431    -0.52195]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_914.jpg: ignoring corrupt image/label: negative label values [   -0.72666    -0.80209]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_915.jpg: ignoring corrupt image/label: negative label values [   -0.95832]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_916.jpg: ignoring corrupt image/label: negative label values [   -0.72667    -0.77246]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_917.jpg: ignoring corrupt image/label: negative label values [   -0.65933    -0.60815]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_918.jpg: ignoring corrupt image/label: negative label values [   -0.84788]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_919.jpg: ignoring corrupt image/label: negative label values [   -0.70512    -0.60815]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_920.jpg: ignoring corrupt image/label: negative label values [   -0.74283    -0.62431]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_921.jpg: ignoring corrupt image/label: negative label values [   -0.82094    -0.86404]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_922.jpg: ignoring corrupt image/label: negative label values [   -0.73475    -0.68357]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_923.jpg: ignoring corrupt image/label: negative label values [   -0.92329]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_924.jpg: ignoring corrupt image/label: negative label values [   -0.82633]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_925.jpg: ignoring corrupt image/label: negative label values [   -0.71589]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_926.jpg: ignoring corrupt image/label: negative label values [    -1.0741]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_927.jpg: ignoring corrupt image/label: negative label values [    -1.3058]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_928.jpg: ignoring corrupt image/label: negative label values [   -0.81286]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_929.jpg: ignoring corrupt image/label: negative label values [    -1.0688]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_930.jpg: ignoring corrupt image/label: negative label values [    -0.8829]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_931.jpg: ignoring corrupt image/label: negative label values [   -0.78862]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_932.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_933.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_934.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_935.jpg: ignoring corrupt image/label: negative label values [  -0.010141]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_936.jpg: ignoring corrupt image/label: negative label values [    -1.7391]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_937.jpg: ignoring corrupt image/label: negative label values [    -1.7478]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_938.jpg: ignoring corrupt image/label: negative label values [    -1.9354]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_942.jpg: ignoring corrupt image/label: negative label values [    -1.8058     -2.0331]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_943.jpg: ignoring corrupt image/label: negative label values [    -1.7314     -1.7769     -1.6529]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_944.jpg: ignoring corrupt image/label: negative label values [    -1.6777     -1.7438     -1.8016]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_945.jpg: ignoring corrupt image/label: negative label values [     -1.686      -1.529]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_946.jpg: ignoring corrupt image/label: negative label values [    -1.4877     -1.3183]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_947.jpg: ignoring corrupt image/label: negative label values [   -0.97674      -2.681]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_948.jpg: ignoring corrupt image/label: negative label values [    -2.1657]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_951.jpg: ignoring corrupt image/label: negative label values [   -0.08015]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_952.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0059      1.3881]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_954.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.172]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_955.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6583]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_957.jpg: ignoring corrupt image/label: negative label values [    -0.6475]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_958.jpg: ignoring corrupt image/label: negative label values [   -0.76535]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_959.jpg: ignoring corrupt image/label: negative label values [   -0.64957]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_960.jpg: ignoring corrupt image/label: negative label values [   -0.67231]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_968.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_969.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_970.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_971.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_972.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_973.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_974.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_975.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_976.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_977.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_978.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_979.jpg: corrupt JPEG restored and saved
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_980.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1767]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_981.jpg: ignoring corrupt image/label: negative label values [  -0.058263]
# train: WARNING: /data_new/Projects/LizaPhotoBank/dataset/objects/images/125_991.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0282]
# Plotting labels to ../yolov5/runs/train/exp7/labels.jpg...
#
# AutoAnchor: 4.01 anchors/target, 0.999 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 800 train, 800 val
# Using 4 dataloader workers
# Logging results to ../yolov5/runs/train/exp7
# Starting training for 3 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#        0/2     5.17G    0.1177   0.03911   0.06299        33       800:  44%|███

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Evaluate model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='../models/model-object-detect.pt')
# Out:
# Using cache found in /home/Kirill.Fomenko/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-6-25 Python-3.8.10 torch-1.10.0+cu102 CUDA:0 (GRID P40-12Q, 12288MiB)
#
# Fusing layers...
# Model summary: 367 layers, 46145973 parameters, 0 gradients, 107.8 GFLOPs
# Adding AutoShape...

# %%
from PIL import Image
im1 = Image.open('/data/images/LizaNew/2_5309971804389900991.JPG') 
im2 = Image.open('/data/images/LizaNew2/post_5d14b69439652.jpg') 
imgs = [im1, im2]
results = model(imgs, size=800)
results.print()
results.show()  # or .show()
# Out:
# image 1/2: 3024x4032 2 autos
# image 2/2: 776x580 1 dog
# Speed: 420.8ms pre-process, 31.9ms inference, 1.3ms NMS per image at shape (2, 3, 800, 800)

# %% [markdown]
# ### Mark Objects and save in DB

# %%
import pandas as pd

# %%
conn = 'postgresql://liza:topsecret@novateam.ddns.net:5434/public'
sql_query = 'select * from "Media"'
sql_ds = pd.read_sql(sql_query, conn)
sql_ds.head()
# Out:
#      id                  mediaName                           mediaPath  \
# 0  4207  20220116_121426_01171.jpg  /LizaNew/20220116_121426_01171.jpg
# 1  4208  20220116_121426_01136.jpg  /LizaNew/20220116_121426_01136.jpg
# 2  4209  20220116_121426_01179.jpg  /LizaNew/20220116_121426_01179.jpg
# 3  4210  20220116_121426_01183.jpg  /LizaNew/20220116_121426_01183.jpg
# 4  4211  20220116_121426_01137.jpg  /LizaNew/20220116_121426_01137.jpg
#
#    mediaSize mediaType                                    mediaPreviewUrl  \
# 0      43467     image  https://downloader.disk.yandex.ru/preview/8fe6...
# 1      44751     image  https://downloader.disk.yandex.ru/preview/d892...
# 2      43951     image  https://downloader.disk.yandex.ru/preview/67ec...
# 3      43823     image  https://downloader.disk.yandex.ru/preview/cab8...
# 4      44758     image  https://downloader.disk.yandex.ru/preview/5f3e...
#
#   title
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
sql_query_2 = 'select * from "_MediaToTags"'
sql_media_to_tags = pd.read_sql(sql_query_2, conn)

# %%
mapping = {
    0: 12,
    1: 11,
    2: 13,
    3: 15,
    4: 16,
    5: 17,
    6: 10,
    7: 14
}

# %%
import os
from tqdm import tqdm
for mediaName in tqdm(sql_ds.mediaName.unique()):
    # mediaName=sql_ds.mediaName.unique()[3]
    media_id = sql_ds[sql_ds['mediaName']==mediaName]['id'].values[0]
    mediaPath=os.path.join('/data','images','LizaNew',mediaName)
    try:
        im=Image.open(mediaPath)
    except:
        print('Except with file %s, pass him' % (mediaPath))
        continue
    imgs = [im]
    results = model(imgs, size=800)
    tags=results.pandas().xyxy[0]['class'].unique()
    for tag in tags:
        try:
            tag_id = mapping[tag]
            pd.DataFrame([{'A':media_id, 'B': tag_id}]).to_sql('_MediaToTags',conn,if_exists='append',index=False)
        except:
            print('keys pair %s and %s already exist. Pass.' % (media_id, tag_id))
# Out:
# keys pair 4207 and 12 already exist. Pass.
# keys pair 4208 and 12 already exist. Pass.
# keys pair 4209 and 12 already exist. Pass.
# keys pair 4210 and 12 already exist. Pass.
# keys pair 4211 and 12 already exist. Pass.
# keys pair 4212 and 12 already exist. Pass.
# keys pair 4212 and 11 already exist. Pass.
# keys pair 4213 and 12 already exist. Pass.
# keys pair 4214 and 12 already exist. Pass.
# keys pair 4215 and 12 already exist. Pass.
# keys pair 4216 and 12 already exist. Pass.
# keys pair 4216 and 10 already exist. Pass.
# keys pair 4217 and 12 already exist. Pass.
# keys pair 4218 and 12 already exist. Pass.
# keys pair 4219 and 12 already exist. Pass.
# keys pair 4221 and 11 already exist. Pass.
# keys pair 4221 and 12 already exist. Pass.
# keys pair 4222 and 11 already exist. Pass.
# keys pair 4222 and 12 already exist. Pass.
# keys pair 4223 and 11 already exist. Pass.
# keys pair 4223 and 12 already exist. Pass.
# keys pair 4223 and 10 already exist. Pass.
# keys pair 4224 and 11 already exist. Pass.
# keys pair 4228 and 15 already exist. Pass.
# keys pair 4251 and 16 already exist. Pass.
# keys pair 4251 and 11 already exist. Pass.
# keys pair 4257 and 12 already exist. Pass.
# keys pair 4261 and 16 already exist. Pass.
# keys pair 4261 and 11 already exist. Pass.
# keys pair 4263 and 14 already exist. Pass.
# keys pair 4271 and 12 already exist. Pass.
# keys pair 4317 and 15 already exist. Pass.
# keys pair 4321 and 15 already exist. Pass.
# keys pair 4322 and 15 already exist. Pass.
# keys pair 4325 and 10 already exist. Pass.
# keys pair 4226 and 11 already exist. Pass.
# keys pair 4226 and 12 already exist. Pass.
# keys pair 4226 and 10 already exist. Pass.
# keys pair 4229 and 11 already exist. Pass.
# keys pair 4229 and 12 already exist. Pass.
# keys pair 4234 and 11 already exist. Pass.
# keys pair 4235 and 11 already exist. Pass.
# keys pair 4236 and 11 already exist. Pass.
# keys pair 4236 and 12 already exist. Pass.
# keys pair 4241 and 17 already exist. Pass.
# keys pair 4243 and 11 already exist. Pass.
# keys pair 4273 and 14 already exist. Pass.
# keys pair 4274 and 12 already exist. Pass.
# keys pair 4275 and 14 already exist. Pass.
# keys pair 4279 and 11 already exist. Pass.
# keys pair 4279 and 14 already exist. Pass.
# keys pair 4280 and 14 already exist. Pass.
# keys pair 4281 and 11 already exist. Pass.
# keys pair 4232 and 12 already exist. Pass.
# keys pair 4232 and 11 already exist. Pass.
# keys pair 4233 and 11 already exist. Pass.
# keys pair 4237 and 17 already exist. Pass.
# keys pair 4240 and 11 already exist. Pass.
# keys pair 4240 and 16 already exist. Pass.
# keys pair 4246 and 15 already exist. Pass.
# keys pair 4246 and 10 already exist. Pass.
# keys pair 4249 and 11 already exist. Pass.
# keys pair 4253 and 16 already exist. Pass.
# keys pair 4255 and 17 already exist. Pass.
# keys pair 4260 and 11 already exist. Pass.
# keys pair 4260 and 16 already exist. Pass.
# keys pair 4264 and 12 already exist. Pass.
# keys pair 4265 and 12 already exist. Pass.
# keys pair 4267 and 12 already exist. Pass.
# keys pair 4268 and 11 already exist. Pass.
# keys pair 4269 and 16 already exist. Pass.
# keys pair 4270 and 14 already exist. Pass.
# keys pair 4272 and 14 already exist. Pass.
# keys pair 4272 and 16 already exist. Pass.
# keys pair 4276 and 14 already exist. Pass.
# keys pair 4277 and 11 already exist. Pass.
# keys pair 4278 and 12 already exist. Pass.
# keys pair 4282 and 11 already exist. Pass.
# keys pair 4283 and 14 already exist. Pass.
# keys pair 4283 and 11 already exist. Pass.
# keys pair 4285 and 11 already exist. Pass.
# keys pair 4286 and 10 already exist. Pass.
# keys pair 4287 and 10 already exist. Pass.
# keys pair 4289 and 14 already exist. Pass.
# keys pair 4284 and 14 already exist. Pass.
# keys pair 4294 and 14 already exist. Pass.
# keys pair 4294 and 11 already exist. Pass.
# keys pair 4295 and 16 already exist. Pass.
# keys pair 4308 and 15 already exist. Pass.
# keys pair 4308 and 11 already exist. Pass.
# keys pair 4316 and 15 already exist. Pass.
# keys pair 4326 and 15 already exist. Pass.
# keys pair 4327 and 15 already exist. Pass.
# keys pair 4329 and 15 already exist. Pass.
# keys pair 4329 and 17 already exist. Pass.
# keys pair 4330 and 15 already exist. Pass.
# keys pair 4331 and 15 already exist. Pass.
# keys pair 4332 and 15 already exist. Pass.
# keys pair 4333 and 14 already exist. Pass.
# keys pair 4333 and 15 already exist. Pass.
# keys pair 4339 and 10 already exist. Pass.
# keys pair 4340 and 15 already exist. Pass.
# keys pair 4340 and 11 already exist. Pass.
# keys pair 4340 and 14 already exist. Pass.
# keys pair 4341 and 15 already exist. Pass.
# keys pair 4342 and 14 already exist. Pass.
# keys pair 4342 and 11 already exist. Pass.
# keys pair 4343 and 15 already exist. Pass.
# keys pair 4343 and 11 already exist. Pass.
# keys pair 4344 and 17 already exist. Pass.
# keys pair 4344 and 11 already exist. Pass.
# keys pair 4290 and 14 already exist. Pass.
# keys pair 4291 and 10 already exist. Pass.
# keys pair 4292 and 14 already exist. Pass.
# keys pair 4293 and 14 already exist. Pass.
# keys pair 4296 and 16 already exist. Pass.
# keys pair 4296 and 11 already exist. Pass.
# keys pair 4296 and 17 already exist. Pass.
# keys pair 4297 and 16 already exist. Pass.
# keys pair 4298 and 10 already exist. Pass.
# keys pair 4298 and 11 already exist. Pass.
# keys pair 4299 and 13 already exist. Pass.
# keys pair 4299 and 11 already exist. Pass.
# keys pair 4300 and 10 already exist. Pass.
# keys pair 4301 and 10 already exist. Pass.
# keys pair 4304 and 10 already exist. Pass.
# keys pair 4305 and 15 already exist. Pass.
# keys pair 4306 and 10 already exist. Pass.
# keys pair 4309 and 15 already exist. Pass.
# keys pair 4310 and 15 already exist. Pass.
# keys pair 4311 and 15 already exist. Pass.
# keys pair 4313 and 15 already exist. Pass.
# keys pair 4314 and 15 already exist. Pass.
# keys pair 4315 and 15 already exist. Pass.
# keys pair 4318 and 15 already exist. Pass.
# keys pair 4318 and 11 already exist. Pass.
# keys pair 4318 and 12 already exist. Pass.
# keys pair 4319 and 15 already exist. Pass.
# keys pair 4323 and 15 already exist. Pass.
# keys pair 4347 and 10 already exist. Pass.
# keys pair 4350 and 12 already exist. Pass.
# keys pair 4352 and 16 already exist. Pass.
# keys pair 4358 and 15 already exist. Pass.
# keys pair 4368 and 12 already exist. Pass.
# keys pair 4369 and 10 already exist. Pass.
# keys pair 4370 and 12 already exist. Pass.
# keys pair 4371 and 10 already exist. Pass.
# keys pair 4338 and 10 already exist. Pass.
# keys pair 4346 and 12 already exist. Pass.
# keys pair 4349 and 10 already exist. Pass.
# keys pair 4351 and 15 already exist. Pass.
# keys pair 4354 and 11 already exist. Pass.
# keys pair 4354 and 10 already exist. Pass.
# keys pair 4357 and 15 already exist. Pass.
# keys pair 4359 and 17 already exist. Pass.
# keys pair 4359 and 15 already exist. Pass.
# keys pair 4367 and 10 already exist. Pass.
# keys pair 4386 and 17 already exist. Pass.
# keys pair 4387 and 17 already exist. Pass.
# keys pair 4387 and 11 already exist. Pass.
# keys pair 4388 and 17 already exist. Pass.
# keys pair 4389 and 17 already exist. Pass.
# keys pair 4390 and 10 already exist. Pass.
# keys pair 4391 and 11 already exist. Pass.
# keys pair 4392 and 17 already exist. Pass.
# keys pair 4393 and 17 already exist. Pass.
# keys pair 4394 and 17 already exist. Pass.
# keys pair 4394 and 11 already exist. Pass.
# keys pair 4395 and 17 already exist. Pass.
# keys pair 4395 and 11 already exist. Pass.
# keys pair 4345 and 10 already exist. Pass.
# keys pair 4348 and 15 already exist. Pass.
# keys pair 4353 and 11 already exist. Pass.
# keys pair 4353 and 12 already exist. Pass.
# keys pair 4360 and 17 already exist. Pass.
# keys pair 4363 and 10 already exist. Pass.
# keys pair 4364 and 11 already exist. Pass.
# keys pair 4365 and 12 already exist. Pass.
# keys pair 4366 and 10 already exist. Pass.
# keys pair 4373 and 11 already exist. Pass.
# keys pair 4373 and 10 already exist. Pass.
# keys pair 4375 and 15 already exist. Pass.
# keys pair 4376 and 10 already exist. Pass.
# keys pair 4378 and 17 already exist. Pass.
# keys pair 4380 and 17 already exist. Pass.
# keys pair 4382 and 15 already exist. Pass.
# keys pair 4401 and 17 already exist. Pass.
# keys pair 4402 and 10 already exist. Pass.
# keys pair 4372 and 11 already exist. Pass.
# keys pair 4372 and 10 already exist. Pass.
# keys pair 4374 and 10 already exist. Pass.
# keys pair 4374 and 11 already exist. Pass.
# keys pair 4377 and 11 already exist. Pass.
# keys pair 4377 and 10 already exist. Pass.
# keys pair 4381 and 15 already exist. Pass.
# keys pair 4383 and 17 already exist. Pass.
# keys pair 4384 and 17 already exist. Pass.
# keys pair 4385 and 17 already exist. Pass.
# keys pair 4403 and 10 already exist. Pass.
# keys pair 4405 and 15 already exist. Pass.
# keys pair 4405 and 17 already exist. Pass.
# keys pair 4411 and 17 already exist. Pass.
# keys pair 4411 and 15 already exist. Pass.
# keys pair 4411 and 10 already exist. Pass.
# keys pair 4412 and 10 already exist. Pass.
# keys pair 4422 and 10 already exist. Pass.
# keys pair 4423 and 17 already exist. Pass.
# keys pair 4424 and 17 already exist. Pass.
# keys pair 4425 and 10 already exist. Pass.
# keys pair 4426 and 10 already exist. Pass.
# keys pair 4427 and 17 already exist. Pass.
# keys pair 4396 and 10 already exist. Pass.
# keys pair 4397 and 12 already exist. Pass.
# keys pair 4398 and 10 already exist. Pass.
# keys pair 4399 and 17 already exist. Pass.
# keys pair 4399 and 11 already exist. Pass.
# keys pair 4400 and 17 already exist. Pass.
# keys pair 4417 and 13 already exist. Pass.
# keys pair 4418 and 12 already exist. Pass.
# keys pair 4419 and 10 already exist. Pass.
# keys pair 4420 and 13 already exist. Pass.
# keys pair 4428 and 10 already exist. Pass.
# keys pair 4432 and 11 already exist. Pass.
# keys pair 4435 and 10 already exist. Pass.
# keys pair 4436 and 13 already exist. Pass.
# keys pair 4461 and 11 already exist. Pass.
# keys pair 4461 and 17 already exist. Pass.
# keys pair 4462 and 13 already exist. Pass.
# keys pair 4463 and 13 already exist. Pass.
# keys pair 4473 and 13 already exist. Pass.
# keys pair 4556 and 17 already exist. Pass.
# keys pair 4404 and 17 already exist. Pass.
# keys pair 4404 and 15 already exist. Pass.
# keys pair 4406 and 17 already exist. Pass.
# keys pair 4407 and 11 already exist. Pass.
# keys pair 4407 and 17 already exist. Pass.
# keys pair 4408 and 11 already exist. Pass.
# keys pair 4409 and 10 already exist. Pass.
# keys pair 4410 and 13 already exist. Pass.
# keys pair 4413 and 17 already exist. Pass.
# keys pair 4414 and 11 already exist. Pass.
# keys pair 4415 and 12 already exist. Pass.
# keys pair 4429 and 11 already exist. Pass.
# keys pair 4429 and 12 already exist. Pass.
# keys pair 4431 and 13 already exist. Pass.
# keys pair 4434 and 13 already exist. Pass.
# keys pair 4437 and 17 already exist. Pass.
# keys pair 4452 and 13 already exist. Pass.
# keys pair 4455 and 11 already exist. Pass.
# keys pair 4457 and 17 already exist. Pass.
# keys pair 4458 and 13 already exist. Pass.
# keys pair 4430 and 13 already exist. Pass.
# keys pair 4433 and 10 already exist. Pass.
# keys pair 4438 and 17 already exist. Pass.
# keys pair 4439 and 17 already exist. Pass.
# keys pair 4440 and 13 already exist. Pass.
# keys pair 4441 and 11 already exist. Pass.
# keys pair 4441 and 12 already exist. Pass.
# keys pair 4442 and 17 already exist. Pass.
# keys pair 4443 and 13 already exist. Pass.
# keys pair 4444 and 11 already exist. Pass.
# keys pair 4445 and 13 already exist. Pass.
# keys pair 4446 and 10 already exist. Pass.
# keys pair 4447 and 10 already exist. Pass.
# keys pair 4448 and 17 already exist. Pass.
# keys pair 4449 and 10 already exist. Pass.
# keys pair 4450 and 13 already exist. Pass.
# keys pair 4451 and 13 already exist. Pass.
# keys pair 4453 and 10 already exist. Pass.
# keys pair 4454 and 11 already exist. Pass.
# keys pair 4460 and 11 already exist. Pass.
# keys pair 4459 and 10 already exist. Pass.
# keys pair 4474 and 17 already exist. Pass.
# keys pair 4480 and 13 already exist. Pass.
# keys pair 4481 and 13 already exist. Pass.
# keys pair 4482 and 13 already exist. Pass.
# Except with file /data/images/LizaNew/IMG_8735.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_7624.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_7509.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_1137.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_7626.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_8736.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_7625.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_8734.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_1134.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_1132 поиск местные.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_3822.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_1133.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_7610.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_7612.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_8737.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_7570.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_7569.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_3824.HEIC, pass him
# Except with file /data/images/LizaNew/IMG_7507.HEIC, pass him
